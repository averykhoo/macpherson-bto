# %%
from bs4 import BeautifulSoup
import csv

# %%
blk95a=BeautifulSoup('''<div _ngcontent-rmu-c32="" class="row mb-5"><div _ngcontent-rmu-c32="" class="col-12 col-md-12 col-lg-7" id="available-grid"><!----><div _ngcontent-rmu-c32="" class="row level" style="display: block;"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#19</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,100</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#18</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,100</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#17</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$604,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$604,700</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#16</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$602,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$602,300</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#15</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">522<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">524<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#14</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">522<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">524<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#13</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">522<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">524<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#12</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">522<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">524<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#11</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">522<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">524<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#10</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">522<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">524<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#09</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">522<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">524<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#08</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">522<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">524<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#07</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">522<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">524<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#06</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">522<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">524<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#05</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">522<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">524<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#04</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">522<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">524<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$549,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$549,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#03</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">522<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">524<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$534,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$534,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#02</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">522<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$537,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">524<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$525,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">526<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$525,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">528<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$525,000</label></button></a><!----><!----><!----><!----></div></div></div></div></div><div _ngcontent-rmu-c32="" class="col-12 col-md-12 col-lg-5" id="available-sidebar"><div _ngcontent-rmu-c32="" class="row"><div _ngcontent-rmu-c32="" class="col-10 col-md-10 order-sm-3 order-md-3 order-lg-1"><!----><!----><!----><p _ngcontent-rmu-c32="" class="mb-5">Please click on unit no. to view information available for this unit</p><!----><!----><!----></div></div><div _ngcontent-rmu-c32="" class="row col-12 col-md-12"><div _ngcontent-rmu-c32="" class="col-4 unitInfoLeft py-1 mr-3 my-1"><label _ngcontent-rmu-c32="" for="floor-06">Unit No.<br _ngcontent-rmu-c32="">Floor Area<br _ngcontent-rmu-c32="">Price</label></div><!----><div _ngcontent-rmu-c32="" class="col-4 unitInfoRight py-1 mr-3 my-1"><label _ngcontent-rmu-c32="" for="floor-06">Not Available</label></div></div></div></div>''')

# %%
blk95b=BeautifulSoup('''<div _ngcontent-rmu-c32="" class="row mb-5"><div _ngcontent-rmu-c32="" class="col-12 col-md-12 col-lg-7" id="available-grid"><!----><div _ngcontent-rmu-c32="" class="row level" style="display: block;"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#19</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">554<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">556<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,100</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#18</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">554<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">556<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,100</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#17</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$604,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$604,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">554<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$604,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">556<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$604,700</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#16</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$602,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$602,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">554<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$602,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">556<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#15</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">554<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">556<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$593,800</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#14</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">554<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">556<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,400</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#13</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">554<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">556<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,000</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#12</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">554<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">556<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$586,600</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#11</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">554<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">556<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$584,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#10</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">554<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">556<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$581,800</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#09</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">554<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">556<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$579,400</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#08</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">554<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">556<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#07</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">554<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">556<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#06</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">554<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">556<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#05</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">554<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">556<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$558,700</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#04</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$549,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">554<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$549,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">556<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$549,500</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#03</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$534,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">554<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$534,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">556<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$540,300</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#02</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">550<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$525,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">552<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$525,000</label></button></a><!----><!----><!----><!----></div></div></div></div></div><div _ngcontent-rmu-c32="" class="col-12 col-md-12 col-lg-5" id="available-sidebar"><div _ngcontent-rmu-c32="" class="row"><div _ngcontent-rmu-c32="" class="col-10 col-md-10 order-sm-3 order-md-3 order-lg-1"><!----><!----><!----><p _ngcontent-rmu-c32="" class="mb-5">Please click on unit no. to view information available for this unit</p><!----><!----><!----></div></div><div _ngcontent-rmu-c32="" class="row col-12 col-md-12"><div _ngcontent-rmu-c32="" class="col-4 unitInfoLeft py-1 mr-3 my-1"><label _ngcontent-rmu-c32="" for="floor-06">Unit No.<br _ngcontent-rmu-c32="">Floor Area<br _ngcontent-rmu-c32="">Price</label></div><!----><div _ngcontent-rmu-c32="" class="col-4 unitInfoRight py-1 mr-3 my-1"><label _ngcontent-rmu-c32="" for="floor-06">Not Available</label></div></div></div></div>''')

# %%
blk95c=BeautifulSoup('''<div _ngcontent-rmu-c32="" class="row mb-5"><div _ngcontent-rmu-c32="" class="col-12 col-md-12 col-lg-7" id="available-grid"><!----><div _ngcontent-rmu-c32="" class="row level" style="display: block;"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#19</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$625,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$625,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$625,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#18</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$625,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$625,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$625,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#17</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$623,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$623,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$623,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#16</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$620,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$620,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$620,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#15</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$612,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$612,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$612,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">576<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">578<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#14</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$609,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$609,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$609,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">576<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">578<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#13</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">576<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">578<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#12</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">576<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">578<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#11</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">576<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">578<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#10</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$575,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$575,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">576<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">578<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#09</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$573,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$573,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">576<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">578<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#08</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">576<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">578<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#07</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$552,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$552,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$552,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">576<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">578<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#06</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$534,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$534,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$534,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">576<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">578<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#05</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$528,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$528,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$528,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">576<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">578<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#04</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$512,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$519,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$519,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">576<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">578<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$549,500</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#03</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$497,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$509,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$509,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">576<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">578<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$534,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#02</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">558<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$488,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">560<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$500,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">562<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$500,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">564<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$537,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">566<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$537,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">568<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$537,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">570<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$537,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">572<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$537,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">574<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$537,200</label></button></a><!----><!----><!----><!----></div></div></div></div></div><div _ngcontent-rmu-c32="" class="col-12 col-md-12 col-lg-5" id="available-sidebar"><div _ngcontent-rmu-c32="" class="row"><div _ngcontent-rmu-c32="" class="col-10 col-md-10 order-sm-3 order-md-3 order-lg-1"><!----><!----><!----><p _ngcontent-rmu-c32="" class="mb-5">Please click on unit no. to view information available for this unit</p><!----><!----><!----></div></div><div _ngcontent-rmu-c32="" class="row col-12 col-md-12"><div _ngcontent-rmu-c32="" class="col-4 unitInfoLeft py-1 mr-3 my-1"><label _ngcontent-rmu-c32="" for="floor-06">Unit No.<br _ngcontent-rmu-c32="">Floor Area<br _ngcontent-rmu-c32="">Price</label></div><!----><div _ngcontent-rmu-c32="" class="col-4 unitInfoRight py-1 mr-3 my-1"><label _ngcontent-rmu-c32="" for="floor-06">Not Available</label></div></div></div></div>''')

# %%
blk97a=BeautifulSoup('''<div _ngcontent-rmu-c32="" class="row mb-5"><div _ngcontent-rmu-c32="" class="col-12 col-md-12 col-lg-7" id="available-grid"><!----><div _ngcontent-rmu-c32="" class="row level" style="display: block;"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#19</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">590<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$625,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$625,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#18</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">590<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$625,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$625,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#17</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">590<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$623,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$623,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#16</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">590<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$620,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$620,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#15</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">584<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">586<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">590<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$612,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$612,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#14</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">584<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">586<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">590<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$609,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$609,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#13</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">584<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">586<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">590<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#12</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">584<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">586<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">590<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#11</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">584<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">586<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">590<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#10</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">584<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">586<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">590<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#09</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">584<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">586<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#08</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">584<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">586<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">590<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#07</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">584<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">586<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">590<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$552,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$552,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#06</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">584<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">586<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">590<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$534,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$534,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#05</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">584<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">586<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">590<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$528,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$528,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#04</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$549,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">584<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$549,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">586<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">590<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$512,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$512,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#03</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$534,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">584<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$534,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">586<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">590<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$497,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$497,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#02</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">580<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$537,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">582<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$512,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">584<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$525,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">586<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$537,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">588<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$537,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">590<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$537,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">592<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$488,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">594<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$488,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">596<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$537,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">598<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$537,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">600<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$537,200</label></button></a><!----><!----><!----><!----></div></div></div></div></div><div _ngcontent-rmu-c32="" class="col-12 col-md-12 col-lg-5" id="available-sidebar"><div _ngcontent-rmu-c32="" class="row"><div _ngcontent-rmu-c32="" class="col-10 col-md-10 order-sm-3 order-md-3 order-lg-1"><!----><!----><!----><p _ngcontent-rmu-c32="" class="mb-5">Please click on unit no. to view information available for this unit</p><!----><!----><!----></div></div><div _ngcontent-rmu-c32="" class="row col-12 col-md-12"><div _ngcontent-rmu-c32="" class="col-4 unitInfoLeft py-1 mr-3 my-1"><label _ngcontent-rmu-c32="" for="floor-06">Unit No.<br _ngcontent-rmu-c32="">Floor Area<br _ngcontent-rmu-c32="">Price</label></div><!----><div _ngcontent-rmu-c32="" class="col-4 unitInfoRight py-1 mr-3 my-1"><label _ngcontent-rmu-c32="" for="floor-06">Not Available</label></div></div></div></div>''')

# %%
blk97b=BeautifulSoup('''<div _ngcontent-rmu-c32="" class="row mb-5"><div _ngcontent-rmu-c32="" class="col-12 col-md-12 col-lg-7" id="available-grid"><!----><div _ngcontent-rmu-c32="" class="row level" style="display: block;"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#19</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#18</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#17</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#16</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#15</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">614<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">616<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#14</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">614<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">616<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#13</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">614<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">616<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#12</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$586,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$586,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">614<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">616<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#11</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$584,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$584,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">614<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">616<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#10</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$581,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$581,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">614<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">616<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#09</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$579,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$579,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">614<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">616<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#08</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">614<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">616<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#07</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">614<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">616<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#06</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">614<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">616<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#05</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$558,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$558,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">614<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">616<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#04</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$561,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$561,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$549,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$549,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$561,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$561,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">614<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">616<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$549,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$561,700</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#03</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$552,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$552,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$540,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$540,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$552,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$552,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">614<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$540,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">616<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$528,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$540,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$552,500</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#02</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">602<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$543,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">604<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$543,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">606<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$531,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">608<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$531,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">610<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$531,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">612<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$531,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">614<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$531,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">616<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$518,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">618<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$518,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">620<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$543,300</label></button></a><!----><!----><!----><!----></div></div></div></div></div><div _ngcontent-rmu-c32="" class="col-12 col-md-12 col-lg-5" id="available-sidebar"><div _ngcontent-rmu-c32="" class="row"><div _ngcontent-rmu-c32="" class="col-10 col-md-10 order-sm-3 order-md-3 order-lg-1"><!----><!----><!----><p _ngcontent-rmu-c32="" class="mb-5">Please click on unit no. to view information available for this unit</p><!----><!----><!----></div></div><div _ngcontent-rmu-c32="" class="row col-12 col-md-12"><div _ngcontent-rmu-c32="" class="col-4 unitInfoLeft py-1 mr-3 my-1"><label _ngcontent-rmu-c32="" for="floor-06">Unit No.<br _ngcontent-rmu-c32="">Floor Area<br _ngcontent-rmu-c32="">Price</label></div><!----><div _ngcontent-rmu-c32="" class="col-4 unitInfoRight py-1 mr-3 my-1"><label _ngcontent-rmu-c32="" for="floor-06">Not Available</label></div></div></div></div>''')

# %%
blk99a=BeautifulSoup('''<div _ngcontent-rmu-c32="" class="row mb-5"><div _ngcontent-rmu-c32="" class="col-12 col-md-12 col-lg-7" id="available-grid"><!----><div _ngcontent-rmu-c32="" class="row level" style="display: block;"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#19</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">626<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#18</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">626<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#17</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">626<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#16</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">626<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#15</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">626<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$593,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$593,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#14</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">626<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#13</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">626<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#12</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">626<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$586,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$586,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#11</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">626<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$584,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$584,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$584,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#10</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">626<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$581,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$581,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$581,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#09</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$579,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$579,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#08</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">626<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#07</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">626<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$558,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#06</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">626<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$552,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#05</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">626<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$558,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$558,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#04</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">626<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$549,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$531,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$543,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$561,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$549,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#03</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$540,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$540,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">626<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$540,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$515,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$528,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$552,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$540,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$528,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$540,300</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#02</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">622<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$531,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">624<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$531,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">626<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$531,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">628<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$506,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">630<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$518,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">632<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$543,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">634<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$531,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">636<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$518,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">638<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$531,100</label></button></a><!----><!----><!----><!----></div></div></div></div></div><div _ngcontent-rmu-c32="" class="col-12 col-md-12 col-lg-5" id="available-sidebar"><div _ngcontent-rmu-c32="" class="row"><div _ngcontent-rmu-c32="" class="col-10 col-md-10 order-sm-3 order-md-3 order-lg-1"><!----><!----><!----><p _ngcontent-rmu-c32="" class="mb-5">Please click on unit no. to view information available for this unit</p><!----><!----><!----></div></div><div _ngcontent-rmu-c32="" class="row col-12 col-md-12"><div _ngcontent-rmu-c32="" class="col-4 unitInfoLeft py-1 mr-3 my-1"><label _ngcontent-rmu-c32="" for="floor-06">Unit No.<br _ngcontent-rmu-c32="">Floor Area<br _ngcontent-rmu-c32="">Price</label></div><!----><div _ngcontent-rmu-c32="" class="col-4 unitInfoRight py-1 mr-3 my-1"><label _ngcontent-rmu-c32="" for="floor-06">Not Available</label></div></div></div></div>''')

# %%
blk99b=BeautifulSoup('''<div _ngcontent-rmu-c32="" class="row mb-5"><div _ngcontent-rmu-c32="" class="col-12 col-md-12 col-lg-7" id="available-grid"><!----><div _ngcontent-rmu-c32="" class="row level" style="display: block;"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#19</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#18</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$607,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$613,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#17</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$604,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$610,800</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#16</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$602,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$608,400</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#15</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">644<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">646<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$593,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$599,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$606,000</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#14</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">644<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">646<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$597,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$603,600</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#13</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">644<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">646<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$595,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$601,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#12</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">644<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">646<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$586,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$592,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$598,800</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#11</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">644<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">646<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$584,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$590,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$596,400</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#10</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">644<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">646<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$581,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$587,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$594,000</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#09</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">644<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">646<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$579,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$585,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$591,600</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#08</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">644<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">646<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$589,200</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#07</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">644<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">646<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$583,100</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#06</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">644<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">646<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$577,000</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#05</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">644<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">646<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$558,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$564,800</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$570,900</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#04</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$549,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$549,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$561,700</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$555,600</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#03</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$540,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$528,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$540,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$540,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$552,500</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$546,400</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$540,300</label></button></a><!----><!----><!----><!----></div></div></div></div><div _ngcontent-rmu-c32="" class="row level"><div _ngcontent-rmu-c32="" class="col-12 d-flex flex-wrap"><div _ngcontent-rmu-c32="" class="col-md-1 col-sm-12 flat-grid floor"><button _ngcontent-rmu-c32="" class="btn btn-text-dark" type="button"><label _ngcontent-rmu-c32="">#02</label></button></div><div _ngcontent-rmu-c32="" class="col-md-11 col-sm-12"><!----><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">640<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$531,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">642<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$518,900</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">648<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$537,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">650<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$531,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">652<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$531,100</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">654<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$543,300</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">656<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$537,200</label></button></a><!----><!----><!----><!----></div><div _ngcontent-rmu-c32="" class="flat-grid unit"><!----><a _ngcontent-rmu-c32=""><button _ngcontent-rmu-c32="" class="btn btn-text-dark select-short-listing"><label _ngcontent-rmu-c32="" align="left" class="px-2" for="unit-06-178">658<br _ngcontent-rmu-c32="">93 sqm<br _ngcontent-rmu-c32="">$531,100</label></button></a><!----><!----><!----><!----></div></div></div></div></div><div _ngcontent-rmu-c32="" class="col-12 col-md-12 col-lg-5" id="available-sidebar"><div _ngcontent-rmu-c32="" class="row"><div _ngcontent-rmu-c32="" class="col-10 col-md-10 order-sm-3 order-md-3 order-lg-1"><!----><!----><!----><p _ngcontent-rmu-c32="" class="mb-5">Please click on unit no. to view information available for this unit</p><!----><!----><!----></div></div><div _ngcontent-rmu-c32="" class="row col-12 col-md-12"><div _ngcontent-rmu-c32="" class="col-4 unitInfoLeft py-1 mr-3 my-1"><label _ngcontent-rmu-c32="" for="floor-06">Unit No.<br _ngcontent-rmu-c32="">Floor Area<br _ngcontent-rmu-c32="">Price</label></div><!----><div _ngcontent-rmu-c32="" class="col-4 unitInfoRight py-1 mr-3 my-1"><label _ngcontent-rmu-c32="" for="floor-06">Not Available</label></div></div></div></div>''')

# %%
blocks = {
    '95a': blk95a,
    '95b': blk95b,
    '95c': blk95c,
    '97a': blk97a,
    '97b': blk97b,
    '99a': blk99a,
    '99b': blk99b,
}

# %%
blocks_processed = {block_name: [line for line in block_soup.prettify().split('\n') if not line.strip()[0] == '<'][:-5] for block_name, block_soup in blocks.items()}
blocks_processed
# Out:
# {'95a': ['         #19',
#   '           526',
#   '           93 sqm',
#   '           $607,100',
#   '           528',
#   '           93 sqm',
#   '           $607,100',
#   '         #18',
#   '           526',
#   '           93 sqm',
#   '           $607,100',
#   '           528',
#   '           93 sqm',
#   '           $607,100',
#   '         #17',
#   '           526',
#   '           93 sqm',
#   '           $604,700',
#   '           528',
#   '           93 sqm',
#   '           $604,700',
#   '         #16',
#   '           526',
#   '           93 sqm',
#   '           $602,300',
#   '           528',
#   '           93 sqm',
#   '           $602,300',
#   '         #15',
#   '           522',
#   '           93 sqm',
#   '           $597,500',
#   '           524',
#   '           93 sqm',
#   '           $597,500',
#   '           526',
#   '           93 sqm',
#   '           $599,900',
#   '           528',
#   '           93 sqm',
#   '           $599,900',
# ...

# %%
rows = []
for block_name, block_lines in blocks_processed.items():
    block_name = block_name.upper()
    row = [block_name]
    floor = None
    for line in block_lines:
        line = line.strip()
        row.append(line)
        if line[0] == '#':
            floor = line
            row = [block_name, floor]
        if line[0] == '$':
            rows.append(row)
            row = [block_name, floor]
rows
# Out:
# [['95A', '#19', '526', '93 sqm', '$607,100'],
#  ['95A', '#19', '528', '93 sqm', '$607,100'],
#  ['95A', '#18', '526', '93 sqm', '$607,100'],
#  ['95A', '#18', '528', '93 sqm', '$607,100'],
#  ['95A', '#17', '526', '93 sqm', '$604,700'],
#  ['95A', '#17', '528', '93 sqm', '$604,700'],
#  ['95A', '#16', '526', '93 sqm', '$602,300'],
#  ['95A', '#16', '528', '93 sqm', '$602,300'],
#  ['95A', '#15', '522', '93 sqm', '$597,500'],
#  ['95A', '#15', '524', '93 sqm', '$597,500'],
#  ['95A', '#15', '526', '93 sqm', '$599,900'],
#  ['95A', '#15', '528', '93 sqm', '$599,900'],
#  ['95A', '#14', '522', '93 sqm', '$597,500'],
#  ['95A', '#14', '524', '93 sqm', '$597,500'],
#  ['95A', '#14', '526', '93 sqm', '$597,500'],
#  ['95A', '#14', '528', '93 sqm', '$597,500'],
#  ['95A', '#13', '522', '93 sqm', '$595,100'],
#  ['95A', '#13', '524', '93 sqm', '$595,100'],
#  ['95A', '#13', '526', '93 sqm', '$595,100'],
#  ['95A', '#13', '528', '93 sqm', '$595,100'],
# ...

# %%
with open('macpherson_prices.csv', 'wt', encoding='ascii', newline='') as f:
    c = csv.writer(f)
    c.writerow(['block', 'floor', 'stack', 'size', 'price'])
    c.writerows(rows)
